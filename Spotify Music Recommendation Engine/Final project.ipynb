# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C://Users//SHUBHAM//Desktop//PROJECT 1//spotify.csv")
df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7   1920-01-05       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17   1920-01-01       0.0425  127.997   0.0422  1920
# 4           2   1920-10-01       0.0768  122.076   0.2990  1920

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
#  16  tempo             174389 non-null  float64
#  17  valence           174389 non-null  float64
#  18  year              174389 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 25.3+ MB

# %%
df.shape
# Out:
# (174389, 19)

# %%
df.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2159

# %%
# examine duplicated rows
df.loc[df.duplicated(), :]
# Out:
#         acousticness                                            artists  \
# 9525         0.56700                                   ['Neil Diamond']
# 9534         0.02710                                   ['Neil Diamond']
# 16113        0.97400  ['Johann Strauss II', 'Riccardo Muti', 'Wiener...
# 16663        0.35500               ['Waylon Jennings', 'Willie Nelson']
# 16669        0.20200                                ['Ten Years After']
# ...              ...                                                ...
# 174380       0.04840                             ['Stephan F', 'YA-YA']
# 174382       0.14100                       ['BigBankCarti', 'Keyvo400']
# 174384       0.00917                 ['DJ Combo', 'Sander-7', 'Tony T']
# 174386       0.80600                                      ['Roger Fly']
# 174388       0.23900                                      ['Roger Fly']
#
#         danceability  duration_ms  energy  explicit                      id  \
# 9525           0.515       180253  0.6410         0  1BmVQ5RGqqtF5cnsv6cQYu
# 9534           0.560       163907  0.8270         0  2SS3WeSe24ZqTlTSK4KzQZ
# 16113          0.219       459053  0.0855         0  5zZbXSRIFe1uWNmEM7f2XI
# 16663          0.626       184267  0.4570         0  0sFq478LIo9BFwf2qzMzzF
# 16669          0.384       224133  0.5160         0  19HjHUjCfDrEYhVSIKG6nK
# ...              ...          ...     ...       ...                     ...
# 174380         0.693       177148  0.8260         0  1Cbf6PLWsL4s51eFepXx6L
# 174382         0.544       215014  0.4070         1  3ASGdyWXeXsXtOIWtm0tv4
# 174384         0.792       147615  0.8660         0  46LhBf6TvYjZU2SMvGZAbn
# 174386         0.671       218147  0.5890         0  48Qj61hOdYmUCFJbpQ29Ob
# 174388         0.677       197710  0.4600         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode  \
# 9525            0.064200    5    0.3220    -5.573     1
# 9534            0.002850    8    0.0551    -4.157     1
# 16113           0.922000    0    0.3550   -19.703     0
# 16663           0.000009    4    0.0668   -13.785     1
# 16669           0.180000    9    0.1140   -12.032     0
# ...                  ...  ...       ...       ...   ...
# 174380          0.000012    1    0.2310    -2.669     1
# 174382          0.000000    4    0.2530   -12.745     0
# 174384          0.000060    6    0.1780    -5.089     0
# 174386          0.920000    4    0.1130   -12.393     0
# 174388          0.891000    7    0.2150   -12.237     1
#
#                                                 name  popularity release_date  \
# 9525                    Girl, You'll Be A Woman Soon          60         1968
# 9534                                   Cherry Cherry          54         1968
# 16113              Frühlingsstimmen, Walzer, Op. 410          34   2021-01-08
# 16663            The Year 2003 Minus 25 - Remastered          43   1978-01-01
# 16669   I'd Love to Change the World - 2004 Remaster          60   1971-11-11
# ...                                              ...         ...          ...
# 174380                     Only Tonight - Radio Edit           0   2020-12-25
# 174382                                         LayUp           0   2020-12-31
# 174384                                       The One           0   2020-12-25
# 174386                                      Together           0   2020-12-09
# 174388                                Improvisations           0   2020-12-09
#
#         speechiness    tempo  valence  year
# 9525         0.0272  109.558    0.655  1968
# 9534         0.0306   84.383    0.904  1968
# 16113        0.0404  171.849    0.156  2021
# 16663        0.0384  102.166    0.474  1978
# 16669        0.0345  118.129    0.371  1971
# ...             ...      ...      ...   ...
# 174380       0.0762  126.049    0.361  2020
# 174382       0.2330  129.750    0.490  2020
# 174384       0.0356  125.972    0.186  2020
# 174386       0.0282  108.058    0.714  2020
# 174388       0.0258  112.208    0.747  2020
#
# [2159 rows x 19 columns]

# %%
data = df.drop_duplicates(keep="first")

# %%
data
# Out:
#         acousticness                    artists  danceability  duration_ms  \
# 0           0.991000            ['Mamie Smith']         0.598       168333
# 1           0.643000  ["Screamin' Jay Hawkins"]         0.852       150200
# 2           0.993000            ['Mamie Smith']         0.647       163827
# 3           0.000173        ['Oscar Velazquez']         0.730       422087
# 4           0.295000                   ['Mixe']         0.704       165224
# ...              ...                        ...           ...          ...
# 174379      0.795000           ['Alessia Cara']         0.429       144720
# 174381      0.795000           ['Alessia Cara']         0.429       144720
# 174383      0.795000           ['Alessia Cara']         0.429       144720
# 174385      0.795000           ['Alessia Cara']         0.429       144720
# 174387      0.920000           ['Taylor Swift']         0.462       244000
#
#         energy  explicit                      id  instrumentalness  key  \
# 0        0.224         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5
# 1        0.517         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5
# 2        0.186         0  11m7laMUgmOKqI3oYzuhne          0.000018    0
# 3        0.798         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2
# 4        0.707         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10
# ...        ...       ...                     ...               ...  ...
# 174379   0.211         0  45XnLMuqf3vRfskEAMUeCH          0.000000    4
# 174381   0.211         0  4pPFI9jsguIh3wC7Otoyy8          0.000000    4
# 174383   0.211         0  52YtxLVUyvtiGPxwwxayHZ          0.000000    4
# 174385   0.211         0  7tue2Wemjd0FZzRtDrQFZd          0.000000    4
# 174387   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP          0.000000    0
#
#         liveness  loudness  mode  \
# 0         0.3790   -12.628     0
# 1         0.0809    -7.261     0
# 2         0.5190   -12.098     1
# 3         0.1280    -7.311     1
# 4         0.4020    -6.036     0
# ...          ...       ...   ...
# 174379    0.1960   -11.665     1
# 174381    0.1960   -11.665     1
# 174383    0.1960   -11.665     1
# 174385    0.1960   -11.665     1
# 174387    0.1130   -12.077     1
#
#                                                      name  popularity  \
# 0                                Keep A Song In Your Soul          12
# 1                                    I Put A Spell On You           7
# 2                                            Golfing Papa           4
# 3       True House Music - Xavier Santos & Carlos Gomi...          17
# 4                                               Xuniverxe           2
# ...                                                   ...         ...
# 174379                                      A Little More           0
# 174381                                      A Little More           0
# 174383                                      A Little More           0
# 174385                                      A Little More           0
# 174387                                 champagne problems          69
#
#        release_date  speechiness    tempo  valence  year
# 0              1920       0.0936  149.976   0.6340  1920
# 1        1920-01-05       0.0534   86.889   0.9500  1920
# 2              1920       0.1740   97.600   0.6890  1920
# 3        1920-01-01       0.0425  127.997   0.0422  1920
# 4        1920-10-01       0.0768  122.076   0.2990  1920
# ...             ...          ...      ...      ...   ...
# 174379   2021-01-22       0.0360   94.710   0.2280  2021
# 174381   2021-01-22       0.0360   94.710   0.2280  2021
# 174383   2021-01-22       0.0360   94.710   0.2280  2021
# 174385   2021-01-22       0.0360   94.710   0.2280  2021
# 174387   2021-01-07       0.0377  171.319   0.3200  2021
#
# [172230 rows x 19 columns]

# %%
df1 = df.drop(columns=['id', 'name', 'artists', 'release_date', 'year'])
df1.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.263217    -0.089169 -0.750852 -0.208176
# danceability         -0.263217      1.000000    -0.100757  0.204838  0.200842
# duration_ms          -0.089169     -0.100757     1.000000  0.060516 -0.033808
# energy               -0.750852      0.204838     0.060516  1.000000  0.102561
# explicit             -0.208176      0.200842    -0.033808  0.102561  1.000000
# instrumentalness      0.221956     -0.215589     0.103621 -0.177750 -0.130609
# key                  -0.028028      0.026266     0.002020  0.035780  0.005282
# liveness             -0.029654     -0.110033     0.028942  0.134815  0.037288
# loudness             -0.546639      0.249541     0.019791  0.779267  0.106249
# mode                  0.064633     -0.048358    -0.046849 -0.056160 -0.062503
# popularity           -0.396744      0.123746     0.024717  0.328939  0.152545
# speechiness          -0.022437      0.239962    -0.097838 -0.112616  0.353872
# tempo                -0.223840      0.005479    -0.008182  0.266448  0.008075
# valence              -0.166968      0.536713    -0.183199  0.326418 -0.009275
#
#                   instrumentalness       key  liveness  loudness      mode  \
# acousticness              0.221956 -0.028028 -0.029654 -0.546639  0.064633
# danceability             -0.215589  0.026266 -0.110033  0.249541 -0.048358
# duration_ms               0.103621  0.002020  0.028942  0.019791 -0.046849
# energy                   -0.177750  0.035780  0.134815  0.779267 -0.056160
# explicit                 -0.130609  0.005282  0.037288  0.106249 -0.062503
# instrumentalness          1.000000 -0.004619 -0.047941 -0.317562 -0.056731
# key                      -0.004619  1.000000 -0.003368  0.025227 -0.127397
# liveness                 -0.047941 -0.003368  1.000000  0.062695  0.001677
# loudness                 -0.317562  0.025227  0.062695  1.000000 -0.019250
# mode                     -0.056731 -0.127397  0.001677 -0.019250  1.000000
# popularity               -0.300625  0.001951 -0.078959  0.337194  0.007652
# speechiness              -0.133966  0.009648  0.122034 -0.213504 -0.040711
# tempo                    -0.068656  0.005009  0.008586  0.217914  0.002438
# valence                  -0.219188  0.025592 -0.005781  0.302520  0.021592
#
#                   popularity  speechiness     tempo   valence
# acousticness       -0.396744    -0.022437 -0.223840 -0.166968
# danceability        0.123746     0.239962  0.005479  0.536713
# duration_ms         0.024717    -0.097838 -0.008182 -0.183199
# energy              0.328939    -0.112616  0.266448  0.326418
# explicit            0.152545     0.353872  0.008075 -0.009275
# instrumentalness   -0.300625    -0.133966 -0.068656 -0.219188
# key                 0.001951     0.009648  0.005009  0.025592
# liveness           -0.078959     0.122034  0.008586 -0.005781
# loudness            0.337194    -0.213504  0.217914  0.302520
# mode                0.007652    -0.040711  0.002438  0.021592
# popularity          1.000000    -0.195329  0.094985  0.063471
# speechiness        -0.195329     1.000000 -0.033530  0.050600
# tempo               0.094985    -0.033530  1.000000  0.163118
# valence             0.063471     0.050600  0.163118  1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df1.corr(),annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# #  VISUALIZATION

# %%
from matplotlib import cm
color = cm.inferno_r(np.linspace(.4, .8, 30))

# %%
plt.figure(figsize=(10,4))
plt.title("Distribution of Popularity Variable.")
sns.distplot(data['popularity'],color='#8B1A1A');

# %%
plt.figure(figsize=(10,3))
plt.title("Boxplot of Popularity Variable.")
sns.boxplot(data=data['popularity'],color='#8B1A1A',orient='horizontal');

# %%
data.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(6,3))
plt.title("Top 10 songs based on Popularity.")
data.groupby('name').mean()['popularity'].sort_values(ascending=False).head(10).plot(kind='bar',colormap='Paired');

# %%
plt.figure(figsize=(10,4))
plt.title("Top 10 Artist based on Popularity.")
data.groupby('artists').mean()['popularity'].sort_values(ascending=False).head(10).plot(kind='bar',color=color,stacked=True)
plt.xlabel('Artists',fontsize=10)
plt.xticks(rotation=-70);

# %%
plt.figure(figsize=(12,4))
plt.suptitle("Duration_ms Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['duration_ms'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['duration_ms'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("danceability Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['danceability'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['danceability'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("energy Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(df['energy'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(df['energy'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("key Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['key'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['key'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("loudness Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['loudness'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['loudness'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("speechiness Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['speechiness'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['speechiness'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("acousticness Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['acousticness'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['acousticness'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("instrumentalness Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['instrumentalness'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['instrumentalness'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("liveness Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['liveness'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['liveness'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("valence Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['valence'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['valence'],color='#8B1A1A');

# %%
plt.figure(figsize=(12,4))
plt.suptitle("tempo Varialble Statisitics.",fontsize=16)
plt.subplot(1,2,1)
sns.distplot(data['tempo'],color='#8B1A1A')
plt.subplot(1,2,2)
sns.boxplot(data['tempo'],color='#8B1A1A');

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# ## Content based Recommendation system

# %%
from sklearn.preprocessing import MinMaxScaler
datatypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
scaler = MinMaxScaler()
normalization = data.select_dtypes(include=datatypes)
normalization = scaler.fit_transform(normalization)

# %%
normalization
# Out:
# array([[0.99497992, 0.60526316, 0.03063657, ..., 0.61590016, 0.634     ,
#         0.        ],
#        [0.64558233, 0.86234818, 0.02723665, ..., 0.35682342, 0.95      ,
#         0.        ],
#        [0.99698795, 0.6548583 , 0.0297917 , ..., 0.40080983, 0.689     ,
#         0.        ],
#        ...,
#        [0.79819277, 0.43421053, 0.02620916, ..., 0.38894159, 0.228     ,
#         1.        ],
#        [0.79819277, 0.43421053, 0.02620916, ..., 0.38894159, 0.228     ,
#         1.        ],
#        [0.92369478, 0.46761134, 0.04482405, ..., 0.70354856, 0.32      ,
#         1.        ]])

# %% [markdown]
# Here I will normalize all the numerical columns, for that, I will be selecting all the columns with int and float datatypes.

# %%
from sklearn.cluster import KMeans

# %%
TWSS = []
k = list(range(1, 15))

for i in k:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df1)
    TWSS.append(kmeans.inertia_)

# %%
plt.plot(k, TWSS, 'ro-');plt.xlabel("No_of_Clusters");plt.ylabel("total_within_SS")
# Out:
# Text(0, 0.5, 'total_within_SS')

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
features = kmeans.fit_predict(normalization)
data['features'] = features

# %%
data
# Out:
#         acousticness                    artists  danceability  duration_ms  \
# 0           0.991000            ['Mamie Smith']         0.598       168333
# 1           0.643000  ["Screamin' Jay Hawkins"]         0.852       150200
# 2           0.993000            ['Mamie Smith']         0.647       163827
# 3           0.000173        ['Oscar Velazquez']         0.730       422087
# 4           0.295000                   ['Mixe']         0.704       165224
# ...              ...                        ...           ...          ...
# 174379      0.795000           ['Alessia Cara']         0.429       144720
# 174381      0.795000           ['Alessia Cara']         0.429       144720
# 174383      0.795000           ['Alessia Cara']         0.429       144720
# 174385      0.795000           ['Alessia Cara']         0.429       144720
# 174387      0.920000           ['Taylor Swift']         0.462       244000
#
#         energy  explicit                      id  instrumentalness  key  \
# 0        0.224         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5
# 1        0.517         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5
# 2        0.186         0  11m7laMUgmOKqI3oYzuhne          0.000018    0
# 3        0.798         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2
# 4        0.707         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10
# ...        ...       ...                     ...               ...  ...
# 174379   0.211         0  45XnLMuqf3vRfskEAMUeCH          0.000000    4
# 174381   0.211         0  4pPFI9jsguIh3wC7Otoyy8          0.000000    4
# 174383   0.211         0  52YtxLVUyvtiGPxwwxayHZ          0.000000    4
# 174385   0.211         0  7tue2Wemjd0FZzRtDrQFZd          0.000000    4
# 174387   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP          0.000000    0
#
#         liveness  loudness  mode  \
# 0         0.3790   -12.628     0
# 1         0.0809    -7.261     0
# 2         0.5190   -12.098     1
# 3         0.1280    -7.311     1
# 4         0.4020    -6.036     0
# ...          ...       ...   ...
# 174379    0.1960   -11.665     1
# 174381    0.1960   -11.665     1
# 174383    0.1960   -11.665     1
# 174385    0.1960   -11.665     1
# 174387    0.1130   -12.077     1
#
#                                                      name  popularity  \
# 0                                Keep A Song In Your Soul          12
# 1                                    I Put A Spell On You           7
# 2                                            Golfing Papa           4
# 3       True House Music - Xavier Santos & Carlos Gomi...          17
# 4                                               Xuniverxe           2
# ...                                                   ...         ...
# 174379                                      A Little More           0
# 174381                                      A Little More           0
# 174383                                      A Little More           0
# 174385                                      A Little More           0
# 174387                                 champagne problems          69
#
#        release_date  speechiness    tempo  valence  year  features
# 0              1920       0.0936  149.976   0.6340  1920         3
# 1        1920-01-05       0.0534   86.889   0.9500  1920         3
# 2              1920       0.1740   97.600   0.6890  1920         4
# 3        1920-01-01       0.0425  127.997   0.0422  1920         2
# 4        1920-10-01       0.0768  122.076   0.2990  1920         1
# ...             ...          ...      ...      ...   ...       ...
# 174379   2021-01-22       0.0360   94.710   0.2280  2021         4
# 174381   2021-01-22       0.0360   94.710   0.2280  2021         4
# 174383   2021-01-22       0.0360   94.710   0.2280  2021         4
# 174385   2021-01-22       0.0360   94.710   0.2280  2021         4
# 174387   2021-01-07       0.0377  171.319   0.3200  2021         4
#
# [172230 rows x 20 columns]

# %%
data[data['features']==0]
# Out:
#         acousticness                                   artists  danceability  \
# 5            0.99600         ['Mamie Smith & Her Jazz Hounds']         0.424
# 8            0.99600                      ['Francisco Canaro']         0.469
# 9            0.00682                                ['Meetya']         0.571
# 11           0.99600                      ['Francisco Canaro']         0.579
# 12           0.99200                              ['Ka Koula']         0.353
# ...              ...                                       ...           ...
# 174124       0.98100                               ['October']         0.520
# 174172       0.85200                       ['caleb scarberry']         0.555
# 174365       0.97600  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.358
# 174369       0.99500  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.297
# 174375       0.98800  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.316
#
#         duration_ms  energy  explicit                      id  \
# 5            198627  0.2450         0  3HnrHGLE9u2MjHtdobfWl9
# 8            146840  0.2380         0  02i59gYdjlhBmbbWhf8YuK
# 9            476304  0.7530         0  06NUxS2XL3efRh0bloxkHm
# 11           167213  0.3560         0  0ANuF7SvPeIHanGcCpy9jR
# 12           285707  0.3960         0  0BEO6nHi1rmTOPiEZvCIDW
# ...             ...     ...       ...                     ...
# 174124       226603  0.1980         0  1g6Zm6BiN3WktHGzu0ZKAh
# 174172       174010  0.2990         1  7Kvz6HUGWyzKpLewRNykaa
# 174365       381150  0.1210         0  0sZ6HFSulsrOl6VTBwp6jd
# 174369       349200  0.0287         0  2LeqqwzobL5ktfQhWA3bHh
# 174375       303333  0.0573         0  6QGVWUbmlePAiY5zJjfCmT
#
#         instrumentalness  key  liveness  loudness  mode  \
# 5                  0.799    5    0.2350   -11.470     1
# 8                  0.960    8    0.1490   -18.717     1
# 9                  0.873    8    0.0920    -6.943     1
# 11                 0.948   10    0.1740   -14.574     1
# 12                 0.924    1    0.3120   -14.053     1
# ...                  ...  ...       ...       ...   ...
# 174124             0.909    1    0.1020   -23.823     1
# 174172             0.690    9    0.1540    -9.661     1
# 174365             0.889    2    0.1350   -25.111     1
# 174369             0.908    8    0.0995   -30.008     1
# 174375             0.879    3    0.1200   -24.121     1
#
#                                                      name  popularity  \
# 5                             Crazy Blues - 78rpm Version           9
# 8                            La Chacarera - Remasterizado           0
# 9                            Broken Puppet - Original Mix           0
# 11                              Desengaño - Remasterizado           0
# 12                                            Ta oula sou           0
# ...                                                   ...         ...
# 174124                      A Good Year - 2020 Remastered           5
# 174172  2020 was the worst year of my fucking life - F...           5
# 174365                                           I giorni           0
# 174369                                     Nuvole bianche           0
# 174375                                              Night           0
#
#        release_date  speechiness    tempo  valence  year  features
# 5              1920       0.0397  103.870   0.4770  1920         0
# 8        1920-07-08       0.0741  130.060   0.6210  1920         0
# 9        1920-01-01       0.0446  126.993   0.1190  1920         0
# 11       1920-07-08       0.0394  131.494   0.7030  1920         0
# 12       1920-01-01       0.0447  111.268   0.5660  1920         0
# ...             ...          ...      ...      ...   ...       ...
# 174124         2013       0.0483  123.976   0.2720  2013         0
# 174172   2021-01-05       0.5970  109.204   0.6180  2021         0
# 174365   2021-01-23       0.0532  131.808   0.1060  2021         0
# 174369   2021-01-23       0.0564  141.636   0.0678  2021         0
# 174375   2021-01-23       0.0515   81.070   0.0373  2021         0
#
# [18541 rows x 20 columns]

# %%
data[data['features']==1]
# Out:
#         acousticness                        artists  danceability  \
# 4           0.295000                       ['Mixe']         0.704
# 23          0.010500          ['Ron van der Kraan']         0.763
# 31          0.032300                     ['Meetya']         0.697
# 34          0.021000     ["The Swingin' Bachelors"]         0.559
# 44          0.000103           ['Two Charming Men']         0.779
# ...              ...                            ...           ...
# 174335      0.303000                ['ZAYN', 'Syd']         0.695
# 174349      0.125000  ['Sfera Ebbasta', 'J Balvin']         0.755
# 174355      0.498000                       ['ZAYN']         0.597
# 174359      0.598000                  ['Sean Paul']         0.735
# 174361      0.105000                   ['Ashnikko']         0.781
#
#         duration_ms  energy  explicit                      id  \
# 4            165224   0.707         1  2hJjbsLCytGsnAHfdsLejp
# 23           324333   0.363         0  0Rfu6umKtRBny2reKydNph
# 31           489012   0.617         0  0Yt4hib6XmdB0YOkVl3QoL
# 34           288293   0.830         0  0bq1lNI8OPhdRQYZZSSnQk
# 44           375015   0.724         0  0vhLeFi24U1oYB0odNNVV3
# ...             ...     ...       ...                     ...
# 174335       191933   0.582         0  4iC9bQomdbH5YPYi4HrECX
# 174349       193555   0.882         1  2GIJ1Lw3ZoYUUYCABVjPcQ
# 174355       196493   0.368         0  3HSUqAErTyFQWLfLdnFVnB
# 174359       211520   0.846         0  1spt3fYeaUNtoZHg3E6wrL
# 174361       172720   0.487         1  660rulYF3eLCuW6rQpiMdL
#
#         instrumentalness  key  liveness  loudness  mode  \
# 4               0.000246   10    0.4020    -6.036     0
# 23              0.000000   10    0.0956   -21.045     0
# 31              0.902000   11    0.1490    -9.510     0
# 34              0.146000   11    0.1870    -7.876     0
# 44              0.887000   11    0.1230    -7.373     0
# ...                  ...  ...       ...       ...   ...
# 174335          0.007690    8    0.0717    -9.405     0
# 174349          0.001420   10    0.1030    -1.957     0
# 174355          0.000000    2    0.1090   -10.151     0
# 174359          0.000000   10    0.1080    -3.110     0
# 174361          0.000000    1    0.0802    -7.301     0
#
#                                   name  popularity release_date  speechiness  \
# 4                            Xuniverxe           2   1920-10-01       0.0768
# 23                  Sweet Reggae Music           1   1920-01-03       0.1690
# 31            Day After - Original Mix           0   1920-01-01       0.0609
# 34                         Voodoo Doll           0   1920-02-29       0.0546
# 44              Brusque - Original Mix           0   1920-01-01       0.0482
# ...                                ...         ...          ...          ...
# 174335  When Love's Around (feat. Syd)          55   2021-01-15       0.1460
# 174349                            Baby           1   2021-01-22       0.0532
# 174355                       Connexion          52   2021-01-15       0.0936
# 174359                        Get Busy           1   2021-01-22       0.0355
# 174361                      Little Boy          61   2021-01-15       0.1670
#
#           tempo  valence  year  features
# 4       122.076    0.299  1920         1
# 23       88.007    0.447  1920         1
# 31      133.982    0.321  1920         1
# 34      107.912    0.352  1920         1
# 44      128.004    0.226  1920         1
# ...         ...      ...   ...       ...
# 174335  173.976    0.346  2021         1
# 174349   99.984    0.606  2021         1
# 174355  171.980    0.590  2021         1
# 174359  100.197    0.725  2021         1
# 174361  129.941    0.327  2021         1
#
# [28082 rows x 20 columns]

# %%
data[data['features']==2]
# Out:
#         acousticness                artists  danceability  duration_ms  \
# 3           0.000173    ['Oscar Velazquez']         0.730       422087
# 13          0.004780           ['Justrock']         0.643       304078
# 20          0.023900  ['Ron van der Kraan']         0.744       215773
# 25          0.250000             ['Jodoli']         0.521       142445
# 37          0.007440  ['Ron van der Kraan']         0.737       225707
# ...              ...                    ...           ...          ...
# 174341      0.353000               ['ZAYN']         0.691       174520
# 174345      0.096500     ['ZAYN', 'Devlin']         0.724       188800
# 174347      0.325000               ['ZAYN']         0.336       164733
# 174351      0.009840       ['Foo Fighters']         0.530       253840
# 174357      0.000032          ['Sean Paul']         0.530       292427
#
#         energy  explicit                      id  instrumentalness  key  \
# 3        0.798         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2
# 13       0.998         0  0DH1IROKoPK5XTglUt9Pq0          0.476000    1
# 20       0.428         0  0MwMyEO5AxYpghTU6gB85H          0.000031    9
# 25       0.776         0  0TT2zA8fatUuvTnPABz3lS          0.000880    1
# 37       0.328         0  0gIniSwikXODTBupqYPCI1          0.000002    0
# ...        ...       ...                     ...               ...  ...
# 174341   0.410         0  2QLhdiuiQjnNviR9veVs6a          0.000000    2
# 174345   0.640         0  1N4aZ62mHHZqNOOJme0G6f          0.000031    9
# 174347   0.430         0  2M9YhtiwNJrGVRvTm2gbnb          0.000636    1
# 174351   0.759         0  3NUmUIyzNLBp8bCFMH8Mif          0.000000    7
# 174357   0.959         0  0VCOLfLPC9oOrc90WGp2r3          0.027300    7
#
#         liveness  loudness  mode  \
# 3         0.1280    -7.311     1
# 13        0.1050    -6.120     1
# 20        0.1060   -21.081     1
# 25        0.1750    -7.919     1
# 37        0.0765   -18.800     1
# ...          ...       ...   ...
# 174341    0.1310    -7.135     1
# 174345    0.2680    -5.545     1
# 174347    0.1430   -11.742     1
# 174351    0.3190    -7.067     1
# 174357    0.3550    -5.648     1
#
#                                                      name  popularity  \
# 3       True House Music - Xavier Santos & Carlos Gomi...          17
# 13                                             Schumacher           0
# 20                                        On a Ragga Trip           8
# 25                              Taro Yard Slaughter House           0
# 37                             Sweat (A La La La La Long)           0
# ...                                                   ...         ...
# 174341                                             Better          55
# 174345                          Windowsill (feat. Devlin)          54
# 174347                                      Unf**kwitable          54
# 174351                                   Waiting On A War          69
# 174357                                 So Fine - TC Remix           0
#
#        release_date  speechiness    tempo  valence  year  features
# 3        1920-01-01       0.0425  127.997   0.0422  1920         2
# 13       1920-01-01       0.0566  124.018   0.6390  1920         2
# 20       1920-01-03       0.0376  140.011   0.5780  1920         2
# 25       1920-01-29       0.2680  159.775   0.5670  1920         2
# 37       1920-01-03       0.0526  172.025   0.7980  1920         2
# ...             ...          ...      ...      ...   ...       ...
# 174341   2021-01-15       0.2450   84.632   0.0904  2021         2
# 174345   2021-01-15       0.1710  149.925   0.2640  2021         2
# 174347   2021-01-15       0.0430  169.087   0.4970  2021         2
# 174351   2021-01-14       0.0351  131.999   0.5020  2021         2
# 174357   2021-01-22       0.1440  173.009   0.2620  2021         2
#
# [55160 rows x 20 columns]

# %%
data[data['features']==3]
# Out:
#         acousticness                                   artists  danceability  \
# 0              0.991                           ['Mamie Smith']         0.598
# 1              0.643                 ["Screamin' Jay Hawkins"]         0.852
# 10             0.952                              ['Dorville']         0.688
# 19             0.993                           ['Amalia Vaka']         0.397
# 26             0.959             ['Athanasía Alexandropoúlou']         0.603
# ...              ...                                       ...           ...
# 174337         0.942                                  ['ZAYN']         0.557
# 174363         0.966  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.269
# 174367         0.966  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.269
# 174371         0.995  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.343
# 174373         0.966  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.269
#
#         duration_ms  energy  explicit                      id  \
# 0            168333  0.2240         0  0cS0A1fUEUd1EW3FcF8AEI
# 1            150200  0.5170         0  0hbkKFIJm7Z05H8Zl9w30f
# 10           150067  0.2200         0  07jrRR1CUUoPb1FLfSy9Jh
# 19           258160  0.4840         0  0LYNwxHYHPW256lO2phedM
# 26           214773  0.3720         0  0UYplqEm5qa4hkEo64C0TW
# ...             ...     ...       ...                     ...
# 174337       187560  0.2920         0  1VBS77pnYxi5FqCE41CHlL
# 174363       424200  0.0926         0  0qQPTWtCFnAI4SucF4ytVb
# 174367       424200  0.0926         0  1Svqb7CX6rQvJpZY3iVBXh
# 174371       206700  0.0165         0  3Glmyv3hbGGTgeR3FZrxJA
# 174373       424200  0.0926         0  4yBReaKJW78ZYCHpc1cfaK
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.000522    5    0.3790   -12.628     0
# 1               0.026400    5    0.0809    -7.261     0
# 10              0.000000    6    0.2620   -15.208     0
# 19              0.179000    5    0.3270   -11.892     0
# 26              0.012900    8    0.1740   -12.666     0
# ...                  ...  ...       ...       ...   ...
# 174337          0.000201   10    0.1060   -14.414     0
# 174363          0.890000    9    0.0992   -24.280     0
# 174367          0.890000    9    0.0992   -24.280     0
# 174371          0.878000    9    0.0774   -30.915     0
# 174373          0.890000    9    0.0992   -24.280     0
#
#                             name  popularity release_date  speechiness  \
# 0       Keep A Song In Your Soul          12         1920       0.0936
# 1           I Put A Spell On You           7   1920-01-05       0.0534
# 10                         Oouin           0         1920       0.8450
# 19         Thelo na se lismoniso           0   1920-01-01       0.0498
# 26            I photoúla, beráti           0   1920-01-01       0.0741
# ...                          ...         ...          ...          ...
# 174337                  Calamity          55   2021-01-15       0.1130
# 174363                  Divenire           0   2021-01-23       0.0609
# 174367                  Divenire           0   2021-01-23       0.0609
# 174371               Una Mattina           0   2021-01-23       0.0455
# 174373                  Divenire           0   2021-01-23       0.0609
#
#           tempo  valence  year  features
# 0       149.976   0.6340  1920         3
# 1        86.889   0.9500  1920         3
# 10       82.024   0.4140  1920         3
# 19       65.485   0.5150  1920         3
# 26      118.351   0.9010  1920         3
# ...         ...      ...   ...       ...
# 174337  141.684   0.0444  2021         3
# 174363  120.323   0.1020  2021         3
# 174367  120.323   0.1020  2021         3
# 174371  126.970   0.1510  2021         3
# 174373  120.323   0.1020  2021         3
#
# [23045 rows x 20 columns]

# %%
class Spotify_Recommendation():
    def __init__(self, dataset):
        self.dataset = dataset
    def recommend(self, songs, amount=1):
        distance = []
        song = self.dataset[(self.dataset.name.str.lower() == songs.lower())].head(1).values[0]
        rec = self.dataset[self.dataset.name.str.lower() != songs.lower()]
        for songs in tqdm(rec.values):
            d = 0
            for col in np.arange(len(rec.columns)):
                if not col in [1, 6, 12, 14, 18]:
                    d = d + np.absolute(float(song[col]) - float(songs[col]))
            distance.append(d)
        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['artists', 'name']
        return rec[columns][:amount]

# %%
recommendations = Spotify_Recommendation(data)
recommendations.recommend("Country Junction", 10)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 172229/172229 [00:09<00:00, 17510.61it/s]
#                         artists                              name
# 116489  ['Buffalo Springfield']                      I Am a Child
# 25                   ['Jodoli']         Taro Yard Slaughter House
# 27454         ['Elvis Presley']                   Shoppin' Around
# 48021   ['Buffalo Springfield']                      I Am a Child
# 6572          ['Sonny Rollins']                      Mambo Bounce
# 26469            ['Danny Kaye']      My Heart Knows A Lovely Song
# 97546          ['June Christy']  A Lovely Way To Spend An Evening
# 166558         ['Roger Miller']                        Aladambama
# 153944               ['Rancid']                        Listed MIA
# 65996          ['Dolly Parton']         Put It off Until Tomorrow

# %% [markdown]
# # Popularity Based Recommedation System

# %%
data.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year  features
# 0          12         1920       0.0936  149.976   0.6340  1920         3
# 1           7   1920-01-05       0.0534   86.889   0.9500  1920         3
# 2           4         1920       0.1740   97.600   0.6890  1920         4
# 3          17   1920-01-01       0.0425  127.997   0.0422  1920         2
# 4           2   1920-10-01       0.0768  122.076   0.2990  1920         1

# %%
data1 = data.groupby('name').mean()['popularity'].sort_values(ascending=False).head(10)

# %%
data1
# Out:
# name
# drivers license           100.0
# Mood (feat. iann dior)     96.0
# positions                  96.0
# 34+35                      94.0
# LA NOCHE DE ANOCHE         94.0
# Therefore I Am             94.0
# WITHOUT YOU                94.0
# Whoopty                    94.0
# DÁKITI                     93.0
# you broke me first         93.0
# Name: popularity, dtype: float64

# %%
import pickle

# %%
pickle.dump(recommendations,open('recommendations.pkl','wb'))
